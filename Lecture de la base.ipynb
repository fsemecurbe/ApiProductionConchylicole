# %%
# !pip install pandas duckdb
# !pip install requests
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/c4/a8/3a61a721472959ab0ce865ef05d10b0d6bfe27ce8801c99f33d4fa996e65/pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/0a/0d/0e3ecece05b7a7e87ab9fb587855548da437a061326fff64a223b6dcb78a/numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 56.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 28.9 MB/s eta 0:00:00:00:0100:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ...

# %%
import pandas as pd
import duckdb
import requests

# %% [markdown]
# On est dans l'environnement du projet, il n'y a pas de proxy reverse l'adresse est locale, c'est à dire http://127.0.0.1:8000/

# %%
url = "http://127.0.0.1:8000/"
requete = "declarationProduction?siret=111222333&commune=28019&espece=palPAPAomoulesurde&tonnes=1000200000.0"
headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

response = requests.post(url + requete, headers=headers)
print(response.status_code)
print(response.text)
# Out:
# 200
# {"message":"Merci pour votre dépot de données siret : 111222333"}

# %%
conn = duckdb.connect(database="production_conchylicole.duckdb", read_only=True)
preview = conn.execute("SELECT * FROM conchyliculture LIMIT 5").df()
print(preview)
conn.close()
# Out:
#        siret commune              espece        tonnes
# 0  111222333   28019            palourde  1.000200e+09
# 1  111222333   28019      palomoulesurde  1.000200e+09
# 2  111222333   28019  palPAPAomoulesurde  1.000200e+09
# 3  222333444   29019      Mytilus edulis  1.000000e+03
